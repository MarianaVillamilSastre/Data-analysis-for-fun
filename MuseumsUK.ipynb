# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('museums.csv', encoding='ISO-8859-1')

# %%
data[data.museum=='BRITISH MUSEUM']
# Out:
#              museum  year  month    visits
# 192  BRITISH MUSEUM  2004      4  403841.0
# 193  BRITISH MUSEUM  2004      5  367435.0
# 194  BRITISH MUSEUM  2004      6  352583.0
# 195  BRITISH MUSEUM  2004      7  504251.0
# 196  BRITISH MUSEUM  2004      8  490457.0
# 197  BRITISH MUSEUM  2004      9  360254.0
# 198  BRITISH MUSEUM  2004     10  455236.0
# 199  BRITISH MUSEUM  2004     11  387258.0
# 200  BRITISH MUSEUM  2004     12  396783.0
# 201  BRITISH MUSEUM  2005      1  327033.0
# 202  BRITISH MUSEUM  2005      2  367113.0
# 203  BRITISH MUSEUM  2005      3  365956.0
# 204  BRITISH MUSEUM  2005      4  372676.0
# 205  BRITISH MUSEUM  2005      5  414362.0
# 206  BRITISH MUSEUM  2005      6  390743.0
# 207  BRITISH MUSEUM  2005      7  400081.0
# 208  BRITISH MUSEUM  2005      8  359917.0
# 209  BRITISH MUSEUM  2005      9  320651.0
# 210  BRITISH MUSEUM  2005     10  405798.0
# 211  BRITISH MUSEUM  2005     11  365994.0
# 212  BRITISH MUSEUM  2005     12  377364.0
# ...

# %%
british=data.loc[data.museum=='BRITISH MUSEUM']

# %%
severalok=british.groupby('year').sum()

# %%
severalok.shape
# Out:
# (17, 2)

# %%
visitas=severalok.visits.values

# %%
severalok.index
# Out:
# Int64Index([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019, 2020],
#            dtype='int64', name=u'year')

# %%
plt.plot(severalok.index,visitas)
plt
